# %% [markdown]
# <a href="https://colab.research.google.com/github/DarlinRamos/Actividad_1/blob/master/Parcial_Ciencia_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Nombre: Darling Mariela Ramos
Código: SMSS172422

URL de la noticia:
https://www.bbc.com/mundo/noticias-58678550

Descripción del fenómeno a estudiar:
El fenómeno a estudiar es el crecimiento del número de usuarios de internet a lo largo del tiempo a nivel mundial. Este crecimiento puede analizarse como una tendencia que cambia con los años, influenciada por factores como la tecnología, acceso a dispositivos y conectividad.

Parámetros a tomar en cuenta:
- Año
- Número de usuarios de internet (en millones)

Algoritmo de regresión a utilizar:
Regresión no lineal (regresión exponencial)

Justificación del algoritmo elegido:
Se selecciona una regresión no lineal porque el crecimiento de usuarios de internet no es constante, sino que aumenta de forma acelerada con el tiempo, lo cual se ajusta mejor a un modelo exponencial.
